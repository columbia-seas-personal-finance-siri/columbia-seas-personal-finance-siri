# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import re

def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f"An error occurred: {e}")
        return None
def extract_author_and_date(input_str):
    # Define regex patterns for author and date
    author_pattern = r'By\s*([\w\s,]*)\s*–'
    date_pattern = r'Updated\s*([\w\s\d,]*)\sat'
    
    # Search for author and date in the input string
    author_match = re.search(author_pattern, input_str)
    date_match = re.search(date_pattern, input_str)
    
    # Initialize variables to hold the extracted data
    author = None
    date = None
    
    # Check if matches were found and extract the data
    if author_match:
        author = author_match.group(1).strip()
    
    if date_match:
        date = date_match.group(1).strip()
        
    return author, date
    
def extract_articles_and_content(html_content):
    # Initialize BeautifulSoup object
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the container that holds all articles
    article_container = soup.find('div', {'class': 'grid grid-cols-2 md:grid-cols-4 lg:grid-cols-1 text-md gap-16px'})
    
    if article_container is None:
        print("Article container not found")
        return None
    
    # Initialize lists to hold scraped data
    article_titles = []
    article_links = []
    article_contents = []
    article_anthor = []
    article_date = [] # This will hold the article contents
    
    # Loop through each article div to get title and href
    for article_div in article_container.find_all('div'):
        title_tag = article_div.find('a', {'class': 'font-medium text-gray-1100'})
        
        if title_tag:
            article_titles.append(title_tag.text)
            article_links.append("https://www.fool.com" +title_tag['href'])
            
    for link in article_links:
        
        html_content = fetch_page(link)
        article_soup = BeautifulSoup(html_content, 'html.parser')

        article_content_div = article_soup.find('div', {'class': 'max-w-full w-full mx-auto tailwind-article-body'})
        if article_content_div:
            article_contents.append(article_content_div.text.strip())
        else:
            article_contents.append("Content not found")
        
        article_anthor_div = article_soup.find('div', {'class': 'font-medium text-gray-800 text-md md:text-lg mb-16px mt-20px md:my-24px'})
        if article_anthor_div:
            a, b = extract_author_and_date(article_anthor_div.text.strip())
            article_anthor.append(a)
            article_date.append(b)
        else:
            article_anthor.append("Content not found")
            article_date.append("Content not found")
       
    
    # Create a DataFrame
    df = pd.DataFrame({
        'Article Title': article_titles,
        'Article Link': article_links,
        'Article Content': article_contents,
        'Article Anthor': article_anthor,
        'Article Date': article_date
    })
    
    return df


# URL of the page to scrape (replace with the actual URL)
url = 'https://www.fool.com/'

# Fetch the HTML content of the page
html_content = fetch_page(url)

# If fetching was successful, proceed to extract card info
if html_content:
    # Extract card info and convert it to a Pandas DataFrame
    df = extract_articles_and_content(html_content)

# %%
df['Label'] = 'Popular Artical'
df['Article Source'] = 'Motley'

# %%
def extract_author_and_date2(given_str):
    date_str = given_str.split("Updated ")[-1].strip()

    # Convert abbreviated month name to full month name for parsing
    date_str = date_str.replace("Jan.", "January").replace("Feb.", "February").replace("Mar.", "March")
    date_str = date_str.replace("Apr.", "April").replace("May", "May").replace("Jun.", "June")
    date_str = date_str.replace("Jul.", "July").replace("Aug.", "August").replace("Sept.", "September")
    date_str = date_str.replace("Oct.", "October").replace("Nov.", "November").replace("Dec.", "December")

        
    return date_str
    
def extract_articles_and_content2(html_content):
    # Initialize BeautifulSoup object
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the container that holds all articles
    article_container = soup.find_all('div', {'class': 'flex dropdown'})
    article_container_2 = article_container[3].find('div', {'class': 'flex justify-between topnav-wrapper p-32px xl:px-0px'})
    # print(article_container_2)
    if article_container_2 is None:
        print("Article container not found")
        return None
    
    # Initialize lists to hold scraped data
    article_titles = []
    article_links = []
    article_contents = []
    article_anthor = []
    article_date = [] # This will hold the article contents
    
    # Loop through each article div to get title and href
    for article_div in article_container_2.find_all('a'):
        if article_div:
            article_links.append(article_div.get('href'))
        link = article_div.get('href')
        html_content = fetch_page(link)
        article_soup = BeautifulSoup(html_content, 'html.parser')

        article_titles_div = article_soup.find('div', {'class': 'block pg-title-item px-0'})
        if article_titles_div:
            article_titles.append(article_titles_div.text.strip())
        else:
            article_titles.append("Content not found")
            
        if article_soup.find('div', {'class': 'creditcard_page'}):
            article_content_div = article_soup.find('div', {'class': 'creditcard_page'})
            article_contents.append(article_content_div.text.strip())
        elif article_soup.find('div', {'class': 'banking_page'}):
            article_content_div = article_soup.find('div', {'class': 'banking_page'})
            article_contents.append(article_content_div.text.strip())
        elif article_soup.find('div', {'class': 'mortgage_page row'}):
            article_content_div = article_soup.find('div', {'class': 'mortgage_page row'})
            article_contents.append(article_content_div.text.strip())
        elif article_soup.find('div', {'class': 'banking_landing_page row'}):
            article_content_div = article_soup.find('div', {'class': 'banking_landing_page row'})
            article_contents.append(article_content_div.text.strip())
        elif article_soup.find('div', {'class': 'loans_page row'}):
            article_content_div = article_soup.find('div', {'class': 'loans_page row'})
            article_contents.append(article_content_div.text.strip())
        elif article_soup.find('div', {'class': 'row'}):
            article_content_div = article_soup.find('div', {'class': 'row'})
            article_contents.append(article_content_div.text.strip())
        else:
            article_contents.append("Content not found")
        
            
        
        article_anthor_div = article_soup.find('div', {'class': 'col-12 col-md author-bio-author'})
        if article_anthor_div:
            article_anthor.append(article_anthor_div.text.strip())
        else:
            article_anthor.append("Content not found")
            
        article_date_div = article_soup.find('div', {'class': 'col-12 fs-12'})
        if article_date_div:
            article_date.append(extract_author_and_date2(article_date_div.text.strip()))
        else:
            article_date.append("Content not found")
        
       
    
    # Create a DataFrame
    df = pd.DataFrame({
        'Article Title': article_titles,
        'Article Link': article_links,
        'Article Content': article_contents,
        'Article Anthor': article_anthor,
        'Article Date': article_date
    })
    
    return df


# URL of the page to scrape (replace with the actual URL)
url = 'https://www.fool.com/'

# Fetch the HTML content of the page
html_content = fetch_page(url)

# If fetching was successful, proceed to extract card info
if html_content:
    # Extract card info and convert it to a Pandas DataFrame
    df2 = extract_articles_and_content2(html_content)

# %%
df2['Label'] = 'Perspnal Finance'
df2['Article Source'] = 'Motley'

# %%
df_all = pd.concat([df, df2]).reset_index(drop=True)

# %%
df_all
# Out:
#                                         Article Title  \
# 0                          Best Stocks to Buy In 2023
# 1                                Top AI Stocks to Buy
# 2                   How to Invest in OpenAI & ChatGPT
# 3                  6 Steps to Learn How to Buy Stocks
# 4                   Top Marijuana Stocks to Invest In
# 5                                    Best ETFs to Buy
# 6                           Top 3 S&P 500 Index Funds
# 7                      5 Top Hydrogen Stocks to Watch
# 8         High-Yield Dividend Stocks to Buy Right Now
# 9                       Dictionary of Financial Terms
# 10                  Best Credit Cards of October 2023
# 11       Best Cash Back Credit Cards for October 2023
# 12  Best Balance Transfer Credit Cards of October ...
# 13           Best Travel Credit Cards of October 2023
# 14  Best 0% APR Credit Cards & No Interest Intro O...
# 15         Best Rewards Credit Cards for October 2023
# 16   Best Credit Cards for Bad Credit of October 2023
# 17   Best High Yield Savings Accounts of October 2023
# 18             Best Checking Accounts of October 2023
# 19                      Best CD Rates of October 2023
# 20                Best Personal Loans of October 2023
# 21      Best Debt Consolidation Loans of October 2023
# 22  Best Mortgage Lenders & Mortgage Rates as of O...
# 23    Best Mortgage Refinance Lenders of October 2023
# 24  Best Mortgage Lenders for First-Time Home Buye...
# 25                   Best FHA Lenders of October 2023
# 26                                  Content not found
# 27          How Credit Cards Work: A Beginner's Guide
# 28                        Beginner's Guide to Banking
# 29                      Beginner's Guide to Mortgages
# 30                                How to Pay Off Debt
# 31                  How to Increase Your Credit Score
#
#                                          Article Link  \
# 0   https://www.fool.com/investing/top-stocks-to-buy/
# 1   https://www.fool.com/investing/stock-market/ma...
# 2   https://www.fool.com/investing/stock-market/ma...
# 3   https://www.fool.com/investing/how-to-invest/s...
# 4   https://www.fool.com/investing/stock-market/ma...
# 5   https://www.fool.com/investing/how-to-invest/e...
# 6   https://www.fool.com/investing/how-to-invest/i...
# 7   https://www.fool.com/investing/stock-market/ma...
# 8   https://www.fool.com/investing/stock-market/ty...
# 9                         https://www.fool.com/terms/
# 10      https://www.fool.com/the-ascent/credit-cards/
# 11  https://www.fool.com/the-ascent/credit-cards/b...
# 12  https://www.fool.com/the-ascent/credit-cards/b...
# 13  https://www.fool.com/the-ascent/credit-cards/b...
# 14  https://www.fool.com/the-ascent/credit-cards/b...
# 15  https://www.fool.com/the-ascent/credit-cards/b...
# 16  https://www.fool.com/the-ascent/credit-cards/b...
# 17  https://www.fool.com/the-ascent/banks/best-sav...
# 18  https://www.fool.com/the-ascent/banks/checking...
# 19  https://www.fool.com/the-ascent/banks/best-cd-...
# 20    https://www.fool.com/the-ascent/personal-loans/
# 21  https://www.fool.com/the-ascent/personal-loans...
# 22  https://www.fool.com/the-ascent/mortgages/best...
# 23  https://www.fool.com/the-ascent/mortgages/best...
# 24  https://www.fool.com/the-ascent/mortgages/best...
# 25  https://www.fool.com/the-ascent/mortgages/best...
# 26   https://www.fool.com/the-ascent/mortgages/rates/
# 27  https://www.fool.com/the-ascent/credit-cards/h...
# 28             https://www.fool.com/the-ascent/banks/
# 29  https://www.fool.com/the-ascent/mortgages/begi...
# 30  https://www.fool.com/the-ascent/personal-finan...
# 31  https://www.fool.com/the-ascent/personal-finan...
#
#                                       Article Content  \
# 0   There are literally thousands of publicly trad...
# 1   Computers excel at crunching numbers but not a...
# 2   In just a few months, ChatGPT, the disruptive ...
# 3   So you've decided to invest in the stock marke...
# 4   The marijuana industry is expected to expand a...
# 5   Exchange-traded funds offer investors an appea...
# 6   S&P 500 index funds are passive investments al...
# 7   Hydrogen is an energy source that emits no gre...
# 8   There's no official definition of a high-yield...
# 9                                   Content not found
# 10  Many or all of the products here are from our ...
# 11  Many or all of the products here are from our ...
# 12  Many or all of the products here are from our ...
# 13  Many or all of the products here are from our ...
# 14  Many or all of the products here are from our ...
# 15  Many or all of the products here are from our ...
# 16  Many or all of the products here are from our ...
# 17  Many or all of the products here are from our ...
# 18  Many or all of the products here are from our ...
# 19  Many or all of the products here are from our ...
# 20  Many or all of the products here are from our ...
# 21  Many or all of the products here are from our ...
# 22  Many or all of the products here are from our ...
# 23  Many or all of the products here are from our ...
# 24  Many or all of the products here are from our ...
# 25  Many or all of the products here are from our ...
# 26  This device is too small\nIf you're on a Galax...
# 27  Many or all of the products here are from our ...
# 28  Many or all of the products here are from our ...
# 29  Many or all of the products here are from our ...
# 30  This device is too small\nIf you're on a Galax...
# 31  This device is too small\nIf you're on a Galax...
#
#                                        Article Anthor        Article Date  \
# 0                                Matthew Frankel, CFP        Sep 11, 2023
# 1                                       Jeremy Bowman        Sep 18, 2023
# 2                                       Jeremy Bowman        Sep 18, 2023
# 3                                Matthew Frankel, CFP        Jul 19, 2023
# 4                                      Keith Speights        Jul 17, 2023
# 5                                     Matthew DiLallo        Aug 22, 2023
# 6                                     Matthew DiLallo        Aug 23, 2023
# 7                                     Matthew DiLallo        Sep 20, 2023
# 8                                     Matthew DiLallo        May 30, 2023
# 9                                   Content not found   Content not found
# 10  By: Matt Koppenheffer\n and Lyle Daly\nOur Cre...  September 28, 2023
# 11             By: Lyle Daly\nOur Credit Cards Expert  September 21, 2023
# 12        By: Brittney Myers\nOur Credit Cards Expert  September 29, 2023
# 13  By: Matt Koppenheffer\n and Lyle Daly\nOur Cre...  September 28, 2023
# 14  By: Lyle Daly\n and Brittney Myers\nOur Credit...  September 27, 2023
# 15  By: Matt Koppenheffer\n and Lyle Daly\nOur Cre...     October 3, 2023
# 16         By: Natasha Etzel\nOur Credit Cards Expert     August 15, 2023
# 17  By: Brendan Byrnes\n and Kailey Hagen\nOur Ban...     October 2, 2023
# 18  By: Kailey Hagen\n and Matt Frankel, CFP®\nOur...  September 27, 2023
# 19  By: Kailey Hagen\n and Matt Frankel, CFP®\nOur...  September 28, 2023
# 20  By: Dana George\n and Robin Hartill, CFP\nOur ...  September 27, 2023
# 21                  By: Dana George\nOur Loans Expert     August 23, 2023
# 22  By: Matt Frankel, CFP®\n and Christy Bieber\nO...     October 2, 2023
# 23       By: Matt Frankel, CFP®\nOur Mortgages Expert         May 9, 2023
# 24       By: Matt Frankel, CFP®\nOur Mortgages Expert     August 17, 2023
# 25  By: Maurie Backman\n and Steven Porrello\nOur ...  September 22, 2023
# 26          By: Kimberly Rotter\nOur Mortgages Expert      March 20, 2023
# 27             By: Lyle Daly\nOur Credit Cards Expert     August 15, 2023
# 28  By: The Ascent Staff\n and David Chang, ChFC®,...  September 20, 2023
# 29           By: Maurie Backman\nOur Mortgages Expert      April 18, 2023
# 30         By: Lyle Daly\nOur Personal Finance Expert   February 22, 2023
# 31  By: Lindsay VanSomeren\n and Kristi Waterworth...     August 15, 2023
#
#                Label Article Source
# 0    Popular Artical         Motley
# 1    Popular Artical         Motley
# 2    Popular Artical         Motley
# 3    Popular Artical         Motley
# 4    Popular Artical         Motley
# 5    Popular Artical         Motley
# 6    Popular Artical         Motley
# 7    Popular Artical         Motley
# 8    Popular Artical         Motley
# 9    Popular Artical         Motley
# 10  Perspnal Finance         Motley
# 11  Perspnal Finance         Motley
# 12  Perspnal Finance         Motley
# 13  Perspnal Finance         Motley
# 14  Perspnal Finance         Motley
# 15  Perspnal Finance         Motley
# 16  Perspnal Finance         Motley
# 17  Perspnal Finance         Motley
# 18  Perspnal Finance         Motley
# 19  Perspnal Finance         Motley
# 20  Perspnal Finance         Motley
# 21  Perspnal Finance         Motley
# 22  Perspnal Finance         Motley
# 23  Perspnal Finance         Motley
# 24  Perspnal Finance         Motley
# 25  Perspnal Finance         Motley
# 26  Perspnal Finance         Motley
# 27  Perspnal Finance         Motley
# 28  Perspnal Finance         Motley
# 29  Perspnal Finance         Motley
# 30  Perspnal Finance         Motley
# 31  Perspnal Finance         Motley

# %%
import json
def save_to_json(df, filename):
    df.to_json(filename, orient='records', lines=True)
    print(f"Data saved to {filename}")

# %%
save_to_json(df_all, 'Motley_updated.json')
# Out:
# Data saved to Motley_updated.json
