# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re

# %%
def fetch_page(url: str) -> str:
    response = requests.get(url)
    if response.status_code != 200:
        return ""
    return response.text

def extract_article_info(article_div) -> dict:
    article_info = {}
    title_tag = article_div.find('a', {'class': 'mdc-link mds-list-group__link'})
    if title_tag:
        article_info['Article Title'] = title_tag.text
        article_info['Article Link'] = "https://www.morningstar.com" + title_tag['href']
    return article_info

def extract_content_and_author(soup: BeautifulSoup) -> dict:
    content_and_author = {}
    article_content_div = soup.find('div', {'class': 'story__body mdc-story-body__mdc'})
    article_author_div = soup.find('div', {'class': 'mdc-metadata__list__mdc'})

    content_and_author['Article Content'] = article_content_div.text.strip() if article_content_div else "Content not found"
    content_and_author['Article Author'] = article_author_div.text.strip() if article_author_div else "Author not found"
    
    return content_and_author

# %%
def extract_articles_and_content(html_content: str, class_name) -> pd.DataFrame:
    soup = BeautifulSoup(html_content, 'html.parser')
    articles = soup.find_all('ul', {'class': class_name})
    
    if not articles:
        print("Article container not found")
        return None

    article_list = []
    
    for article_div in articles[0].find_all('li', {'class': 'mdc-list-group__item mds-list-group__item mdc-list-group-content-module'}):
        article_info = extract_article_info(article_div)
        if article_info:
            article_html = fetch_page(article_info['Article Link'])
            article_soup = BeautifulSoup(article_html, 'html.parser')
            content_and_author = extract_content_and_author(article_soup)
            article_info.update(content_and_author)
            article_list.append(article_info)
    for article_div in articles[1].find_all('li', {'class': 'mdc-list-group__item mds-list-group__item mdc-list-group-content-module'}):
        article_info = extract_article_info(article_div)
        if article_info:
            article_html = fetch_page(article_info['Article Link'])
            article_soup = BeautifulSoup(article_html, 'html.parser')
            content_and_author = extract_content_and_author(article_soup)
            article_info.update(content_and_author)
            article_list.append(article_info)
            
    return pd.DataFrame(article_list)

# %%
def extract_articles_and_content2(html_content,class_name):
    # Initialize BeautifulSoup object
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the container that holds all articles
    articles = soup.find('div', {'class': class_name})
    articles_all = articles.find_all('div', {'class': 'mdc-grid-item__inner'})
    if articles is None:
        print("Article container not found")
        return None
    
    # Initialize lists to hold scraped data
    article_titles = []
    article_links = []
    article_contents = []
    article_anthor = []
    article_date = [] # This will hold the article contents
    
    # Loop through each article div to get title and href
    for article_div in articles_all:
        title_tag = article_div.find('a', {'class': 'mdc-link mdc-grid-item__title mdc-grid-item__title--link'})
        if title_tag:
            article_titles.append(title_tag.text)
            article_links.append("https://www.morningstar.com" +title_tag['href'])
        
        title_tag_2 = article_div.find('a', {'class': 'mdc-link mdc-grid-item__title mdc-grid-item__title--link mdc-grid-item__title--floated-supplemental-content'})
        if title_tag_2:
            article_titles.append(title_tag_2.text)
            article_links.append("https://www.morningstar.com" +title_tag_2['href'])  
            
    for link in article_links:
        
        html_content = fetch_page(link)
        article_soup = BeautifulSoup(html_content, 'html.parser')

        article_content_div = article_soup.find('div', {'class': 'story__body mdc-story-body__mdc'})
        if article_content_div:
            article_contents.append(article_content_div.text.strip())
        else:
            article_contents.append("Content not found")
        
        article_anthor_div = article_soup.find('div', {'class': 'mdc-metadata__list__mdc'})
        if article_anthor_div:
            article_anthor.append(article_anthor_div.text.strip())
        else:
            article_anthor.append("Content not found")
       
    
    # Create a DataFrame
    df = pd.DataFrame({
        'Article Title': article_titles,
        'Article Link': article_links,
        'Article Content': article_contents,
        'Article Author': article_anthor
    })
    
    return df

# %%
url = 'https://www.morningstar.com/save-for-college'

# Fetch the HTML content of the page
html_content = fetch_page(url)

# If fetching was successful, proceed to extract card info
if html_content:
    # Extract card info and convert it to a Pandas DataFrame
    df1 = extract_articles_and_content(html_content,'mdc-list-group mds-list-group save-for-college__links-group')
    df1['Label'] = 'save-for-college'
    df2 = extract_articles_and_content2(html_content,'mdc-topic-grid__inner mdc-topic-grid__inner--5')
    df2['Label'] = 'save-for-college'

# %%
url2 = 'https://www.morningstar.com/start-investing'

# Fetch the HTML content of the page
html_content2 = fetch_page(url2)

# If fetching was successful, proceed to extract card info
if html_content2:
    # Extract card info and convert it to a Pandas DataFrame
    df3 = extract_articles_and_content(html_content2,'mdc-list-group mds-list-group start-investing__links-group')
    df3['Label'] = 'start-investing'
    df4 = extract_articles_and_content2(html_content2,'mdc-topic-grid__inner mdc-topic-grid__inner--7')
    df4['Label'] = 'start-investing'

# %%
url3 = 'https://www.morningstar.com/portfolios'

# Fetch the HTML content of the page
html_content3 = fetch_page(url3)

# If fetching was successful, proceed to extract card info
if html_content3:
    # Extract card info and convert it to a Pandas DataFrame
    df5 = extract_articles_and_content2(html_content3,'mdc-topic-grid__inner mdc-topic-grid__inner--20')
    df5['Label'] = 'Protfolio'

# %%
df = pd.concat([df1, df2,df3,df4,df5]).reset_index(drop=True)

# %%
df['Article Title'] = df['Article Title'].str.replace(r'[\n\t]', '', regex=True)
df['Article Author'] = df['Article Author'].str.replace(r'[\n\t]', '', regex=True)

# %%
df['Article Source'] = 'Morningstar'

# %%
def extract_date(s):
    match = re.search(r'((?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\s\d{1,2},\s\d{4})', s)
    return match.group(0) if match else None
def extract_author(s, date):
    return s.replace(date, '').strip() if date else s

# %%
df['Article Date'] = df['Article Author'].apply(extract_date)
df['Article Author'] = df.apply(lambda row: extract_author(row['Article Author'], row['Article Date']), axis=1)

# %%
df
# Out:
#                                         Article Title  \
# 0          Do 529 Plans Have Contribution Limits?
# 1    5 Charts Tracking Recent 529 Savings Plan Tre...
# 2                           Myths About 529 Plans
# 3             What Is a 529 College Savings Plan?
# 4        Vanguard Maintains Its Lead in 529 Plans
# 5      How to Allocate Assets for College Savings
# 6    3 Themes Shaping the Future of 529 Savings Pl...
# 7       When Should You Start Saving for College?
# 8    What Bad Returns at the Wrong Time Can Mean f...
# 9    How to Avoid Paying Extra Taxes on Your Colle...
# 10     529 Plans: What’s Changed and What’s the Same?
# 11                              2 Top-Rated 529 Plans
# 12  Morningstar 529 Ratings: The Top Plans and Wha...
# 13                   The Best Way to Save for College
# 14                What Is a 529 College Savings Plan?
# 15                  How to Invest In Your 401(k)
# 16   Roth or Traditional IRA: Which Should You Cho...
# 17                                What Is an HSA?
# 18   What Does It Take to Have a $1 Million 401(k)...
# 19         Morningstar's Guide to Stock Investing
# 20        Key Factors for Evaluating Mutual Funds
# 21                    What Are Target-Date Funds?
# 22               What Is an Exchange-Traded Fund?
# 23                    Financial Tips for Young Adults
# 24                  How to Invest Like Warren Buffett
# 25                What Is a 529 College Savings Plan?
# 26  Should I Start Investing With Stocks or Mutual...
# 27               How Much Should I Have in My 401(k)?
# 28              7 Great Investing Books for Beginners
# 29              Best Investing Podcasts for Beginners
# 30         How to Use Allocation Funds in a Portfolio
# 31     It’s Too Soon to Say the Value Premium Is Dead
# 32  Portfolio Basics: How to Build an Investment P...
# 33         Best Investments to Own During a Recession
# 34                             Why I Don’t Own a Home
# 35  A Crucial Tipping Point for Bond Investors to ...
# 36                     How to Use Cash in a Portfolio
# 37  How to Use International Stocks in Your Portfolio
# 38  The 60/40 Portfolio Isn’t Dead, and Neither Is...
# 39      How Do I Use Large-Cap Stocks in a Portfolio?
# 40            Are Younger Investors Too Conservative?
# 41               7 Things I Don’t Own in My Portfolio
# 42                What To Do With Your Cash Right Now
# 43               Is International Investing Obsolete?
# 44                   Where to Invest in Bonds in 2023
# 45  Why Large-Blend Funds Should Outweigh Value Pl...
# 46  Is It Time to Break Up With the Bonds in Your ...
# 47             What I’ve Done Right With My Portfolio
# 48         Taking the Slow Road to Investment Success
# 49  Should Emerging Markets Play a Role in Your Po...
#
#                                          Article Link  \
# 0   https://www.morningstar.com/articles/1094567/d...
# 1   https://www.morningstar.com/articles/1095648/5...
# 2   https://www.morningstar.com/articles/1094568/m...
# 3   https://www.morningstar.com/articles/1095553/w...
# 4   https://www.morningstar.com/articles/1094478/v...
# 5   https://www.morningstar.com/articles/844386/ho...
# 6   https://www.morningstar.com/articles/1040262/3...
# 7   https://www.morningstar.com/articles/1010710/w...
# 8   https://www.morningstar.com/articles/1003382/w...
# 9   https://www.morningstar.com/articles/983931/ho...
# 10  https://www.morningstar.com/personal-finance/t...
# 11  https://www.morningstar.com/personal-finance/2...
# 12  https://www.morningstar.com/articles/1122373/m...
# 13  https://www.morningstar.com/articles/1117187/t...
# 14  https://www.morningstar.com/specials/what-is-a...
# 15  https://www.morningstar.com/articles/993124/ho...
# 16  https://www.morningstar.com/articles/942793/ro...
# 17  https://www.morningstar.com/articles/965982/wh...
# 18  https://www.morningstar.com/articles/878897/wh...
# 19  https://www.morningstar.com/articles/988220/mo...
# 20  https://www.morningstar.com/articles/990067/ke...
# 21  https://www.morningstar.com/articles/808120/wh...
# 22  https://www.morningstar.com/articles/952709/wh...
# 23  https://www.morningstar.com/articles/1111512/f...
# 24  https://www.morningstar.com/articles/963821/ho...
# 25  https://www.morningstar.com/specials/what-is-a...
# 26  https://www.morningstar.com/articles/985066/sh...
# 27  https://www.morningstar.com/articles/1129518/h...
# 28  https://www.morningstar.com/articles/942483/7-...
# 29  https://www.morningstar.com/articles/1040797/b...
# 30  https://www.morningstar.com/portfolios/how-use...
# 31  https://www.morningstar.com/portfolios/its-too...
# 32  https://www.morningstar.com/portfolios/portfol...
# 33  https://www.morningstar.com/portfolios/best-in...
# 34  https://www.morningstar.com/portfolios/why-i-d...
# 35  https://www.morningstar.com/portfolios/crucial...
# 36  https://www.morningstar.com/portfolios/how-use...
# 37  https://www.morningstar.com/portfolios/how-use...
# 38  https://www.morningstar.com/portfolios/6040-is...
# 39  https://www.morningstar.com/portfolios/how-do-...
# 40  https://www.morningstar.com/portfolios/are-you...
# 41  https://www.morningstar.com/portfolios/7-thing...
# 42  https://www.morningstar.com/portfolios/what-do...
# 43  https://www.morningstar.com/portfolios/is-inte...
# 44  https://www.morningstar.com/portfolios/where-i...
# 45  https://www.morningstar.com/portfolios/why-lar...
# 46  https://www.morningstar.com/portfolios/with-ca...
# 47  https://www.morningstar.com/portfolios/what-i-...
# 48  https://www.morningstar.com/portfolios/bill-be...
# 49  https://www.morningstar.com/portfolios/should-...
#
#                                       Article Content  \
# 0   Susan Dziubinski: Hi, I'm Susan Dziubinski wit...
# 1   The impetus for introducing 529 college saving...
# 2   Susan Dziubinski: Hi, I'm Susan Dziubinski wit...
# 3                                   Content not found
# 4   Assets in 529 savings accounts grew over the c...
# 5   A version of this article was originally publi...
# 6   As a graduation month, May augurs promise. Stu...
# 7   Susan Dziubinski: Hi, I'm Susan Dziubinski wit...
# 8   I’ve written a couple of articles about how se...
# 9   Editor’s note: Read the latest on how the coro...
# 10  Since their launch more than 20 years ago, 529...
# 11  Morningstar currently rates 54 529 plans, repr...
# 12  Morningstar’s team of manager research analyst...
# 13  Susan Dziubinski: Hi, I'm Susan Dziubinski wit...
# 14                                  Content not found
# 15  Editor's note: This article originally ran on ...
# 16  Editor’s note: A version of this article was i...
# 17  A health savings account offers powerful tax b...
# 18  Editor's note: This article originally ran on ...
# 19  At Morningstar, we take an owner-oriented appr...
# 20  If you're currently saving for retirement--or ...
# 21  Editor’s note: A version of this article ran o...
# 22  Editor's note: This article originally ran on ...
# 23  Over the summer, I hit a milestone: I turned 2...
# 24  Warren Buffett is undoubtedly one of the most ...
# 25                                  Content not found
# 26  Many new investors might put their money in st...
# 27  If you ask any Morningstar specialist for advi...
# 28  Learning about financial concepts can feel int...
# 29  There is investing advice for everyone, from c...
# 30  Should you have an allocation fund in your por...
# 31  The underperformance of U.S. value stocks sinc...
# 32  What should be in your investment portfolio?Th...
# 33  The market has been anticipating a recession f...
# 34  Most Americans’ biggest asset, and primary sou...
# 35  After years of sleepwalking along at modest le...
# 36  Should you have cash in your portfolio? It dep...
# 37  Should you have international stocks in your p...
# 38  Bitcoin has performed surprisingly well for th...
# 39  What should be in your portfolio? The specific...
# 40  Last month, my esteemed colleague John Rekenth...
# 41  As someone who writes about building portfolio...
# 42  Ruth Saldanha: Netflix’s no-password-sharing h...
# 43  Companies worldwide are generating more of the...
# 44  Investing in Bonds in 2023Begin to lengthen du...
# 45  Large-blend funds have much to recommend them....
# 46  Investors concerned about inflation have many ...
# 47  If you read my column last week, you might hav...
# 48  Part of the StoryIn 2021, I wrote a column cal...
# 49  Emerging-markets investors haven’t been feelin...
#
#                        Article Author             Label Article Source  \
# 0     Patricia Oey,  Susan Dziubinski  save-for-college    Morningstar
# 1                        Patricia Oey  save-for-college    Morningstar
# 2     Patricia Oey,  Susan Dziubinski  save-for-college    Morningstar
# 3                    Author not found  save-for-college    Morningstar
# 4                        Patricia Oey  save-for-college    Morningstar
# 5                      Christine Benz  save-for-college    Morningstar
# 6                       Madeline Hume  save-for-college    Morningstar
# 7    Madeline Hume,  Susan Dziubinski  save-for-college    Morningstar
# 8                          Amy Arnott  save-for-college    Morningstar
# 9                      Margaret Giles  save-for-college    Morningstar
# 10                        Hyunmin Kim  save-for-college    Morningstar
# 11                        Hyunmin Kim  save-for-college    Morningstar
# 12                       Patricia Oey  save-for-college    Morningstar
# 13  Christine Benz,  Susan Dziubinski  save-for-college    Morningstar
# 14                  Content not found  save-for-college    Morningstar
# 15                      Josh Charlson   start-investing    Morningstar
# 16                      Karen Wallace   start-investing    Morningstar
# 17                    Michael Schramm   start-investing    Morningstar
# 18                      Karen Wallace   start-investing    Morningstar
# 19                   Susan Dziubinski   start-investing    Morningstar
# 20                      Karen Wallace   start-investing    Morningstar
# 21                      Karen Wallace   start-investing    Morningstar
# 22                      Karen Wallace   start-investing    Morningstar
# 23                  Carole Hodorowicz   start-investing    Morningstar
# 24                   Susan Dziubinski   start-investing    Morningstar
# 25                  Content not found   start-investing    Morningstar
# 26                    Michael Schramm   start-investing    Morningstar
# 27                  Carole Hodorowicz   start-investing    Morningstar
# 28                  Carole Hodorowicz   start-investing    Morningstar
# 29                  Carole Hodorowicz   start-investing    Morningstar
# 30                         Amy Arnott         Protfolio    Morningstar
# 31                      Larry Swedroe         Protfolio    Morningstar
# 32                         Amy Arnott         Protfolio    Morningstar
# 33                         Amy Arnott         Protfolio    Morningstar
# 34                      Madeline Hume         Protfolio    Morningstar
# 35                      Madeline Hume         Protfolio    Morningstar
# 36                         Amy Arnott         Protfolio    Morningstar
# 37                         Amy Arnott         Protfolio    Morningstar
# 38                      Madeline Hume         Protfolio    Morningstar
# 39                         Amy Arnott         Protfolio    Morningstar
# 40                      Madeline Hume         Protfolio    Morningstar
# 41                         Amy Arnott         Protfolio    Morningstar
# 42            Morningstar Morningstar         Protfolio    Morningstar
# 43   Dan Lefkovitz,  Susan Dziubinski         Protfolio    Morningstar
# 44                       David Sekera         Protfolio    Morningstar
# 45                         Amy Arnott         Protfolio    Morningstar
# 46                      Madeline Hume         Protfolio    Morningstar
# 47                     Christine Benz         Protfolio    Morningstar
# 48                   John Rekenthaler         Protfolio    Morningstar
# 49                         Amy Arnott         Protfolio    Morningstar
#
#     Article Date
# 0   May 20, 2022
# 1   May 25, 2022
# 2   May 20, 2022
# 3           None
# 4   May 17, 2022
# 5   Jan 19, 2022
# 6   May 20, 2021
# 7    Dec 1, 2020
# 8    Oct 5, 2020
# 9   May 11, 2020
# 10  Jun 12, 2023
# 11  May 22, 2023
# 12   Nov 2, 2022
# 13  Oct 11, 2022
# 14          None
# 15   May 7, 2021
# 16   Feb 2, 2021
# 17  Sep 28, 2021
# 18   May 7, 2021
# 19  Jun 15, 2020
# 20  Jul 30, 2020
# 21  Mar 11, 2022
# 22   May 7, 2021
# 23   May 4, 2023
# 24  Aug 16, 2023
# 25          None
# 26  May 21, 2020
# 27  Jan 18, 2023
# 28  Jul 11, 2023
# 29  Jul 11, 2023
# 30   Oct 2, 2023
# 31  Sep 27, 2023
# 32  Sep 26, 2023
# 33  Sep 25, 2023
# 34  Sep 18, 2023
# 35   Sep 5, 2023
# 36  Aug 28, 2023
# 37  Aug 21, 2023
# 38  Aug 14, 2023
# 39   Aug 7, 2023
# 40   Aug 1, 2023
# 41  Jul 31, 2023
# 42  Jul 28, 2023
# 43  Jul 26, 2023
# 44  Jul 21, 2023
# 45  Jul 17, 2023
# 46  Jul 17, 2023
# 47  Jul 14, 2023
# 48  Jul 13, 2023
# 49  Jul 10, 2023

# %%
import json
def save_to_json(df, filename):
    df.to_json(filename, orient='records', lines=True)
    print(f"Data saved to {filename}")

# %%
save_to_json(df, 'morning_invest_updated.json')
# Out:
# Data saved to morning_invest_updated.json
